# %%
# %%time
import time
import lightgbm as lgb
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import KFold, StratifiedKFold, RepeatedStratifiedKFold
from sklearn.model_selection import train_test_split
import warnings
import gc
import time
import optuna
import sys
import datetime
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from sklearn.decomposition import KernelPCA
from sklearn.metrics import roc_auc_score, roc_curve


warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')
from sklearn import metrics
# Out:
# CPU times: user 450 µs, sys: 5.03 ms, total: 5.48 ms
# Wall time: 14.1 ms

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")


# var_0, var_1, ...
features = [c for c in train_df.columns if c not in ['ID_code', 'target']]
target = train_df['target']

display(train_df.head())
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7   ...     var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266   ...      4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338   ...      7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155   ...      2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250   ...      4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514   ...     -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
# 2  -6.5213   8.2675  14.7222   0.3965
# 3  -2.9275  10.2922  17.9697  -8.9996
# 4   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
train_df.shape
# Out:
# (200000, 202)

# %%
A = np.array(train_df[features])
B = np.array(test_df[features])
pca = PCA(n_components=2)

A_ = pca.fit_transform(A)
B_ = pca.transform(B)

label0, label1 = [], []
for data, label in zip(A_, target):
    if label == 1:
        label1.append(data)
    else:
        label0.append(data)
label0 = np.asarray(label0)
label1 = np.asarray(label1)

plt.scatter(label0[:, 0], label0[:, 1], color="blue", label="label0", s=0.001)
plt.scatter(label1[:, 0], label1[:, 1], color="red", label="label1", s=0.01)
plt.show()

# %% [markdown]
# # Hyperparmeter Search

# %%
data = np.array(train_df[features])
target_arr = np.asarray(train_df['target'])

dev_x, test_x, dev_y, test_y = train_test_split(data, target_arr, test_size=0.25, stratify=target, random_state=2018)
train_x, val_x, train_y, val_y = train_test_split(dev_x, dev_y, test_size=0.3, stratify=dev_y,  random_state=2018)

def objective(trial):
    param = {
        "pca_type" : trial.suggest_categorical('pca_type', ['linear', 'kernel']),
        'pca_dim' : trial.suggest_int('pca_dim', 1, 100),
        'objective': 'binary',
        'metric': 'auc',
        'verbosity': -1,
        'num_iterations' : 10000,
        'boosting_type': trial.suggest_categorical('boosting', ['gbdt', 'dart', 'goss']),
        'num_leaves': trial.suggest_int('num_leaves', 10, 1000),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
        'min_data_in_leaf' : trial.suggest_int('min_data_in_leaf', 2, 1000),
        'max_depth' : trial.suggest_int('max_depth', -1, 100)
    }
    if param["pca_type"] == "linear":
        pca = PCA(n_components=param["pca_dim"])
    else:
        kernel = trial.suggest_categorical('pca_kernel', ["linear", "poly", "rbf", "sigmoid", "cosine", "precomputed"])
        pca = KernelPCA(n_components=param["pca_dim"], kernel=kernel)
        
    train_X_transformed = pca.fit_transform(train_x)
    val_X_transformed = pca.transform(val_x)
    
    train_X_expanded = np.hstack((train_x, train_X_transformed))
    val_X_expanded = np.hstack((val_x, val_X_transformed))
    
    print("train, val, test:  {}, {}, {}".format(train_x.shape, val_x.shape, test_x.shape))
    
    dtrain = lgb.Dataset(train_X_expanded, label=train_y)
    dval = lgb.Dataset(val_X_expanded, label=val_y)

    

    if param['boosting_type'] == 'dart':
        param['drop_rate'] = trial.suggest_loguniform('drop_rate', 1e-8, 1.0)
        param['skip_drop'] = trial.suggest_loguniform('skip_drop', 1e-8, 1.0)
    if param['boosting_type'] == 'goss':
        param['top_rate'] = trial.suggest_uniform('top_rate', 0.0, 1.0)
        param['other_rate'] = trial.suggest_uniform('other_rate', 0.0, 1.0 - param['top_rate'])

    gbm = lgb.train(param, dtrain, early_stopping_rounds=100, valid_sets = [dtrain, dval], verbose_eval=1000)
    preds = gbm.predict(test_x,  num_iteration=gbm.best_iteration)
    auc_score = roc_auc_score(test_y, preds)
    return 1.0 - auc_score


if __name__ == '__main__':
    study = optuna.create_study()
    study.optimize(objective, n_trials=50)

    print('Number of finished trials: {}'.format(len(study.trials)))

    print('Best trial:')
    trial = study.best_trial

    print('  Value: {}'.format(trial.value))

    print('  Params: ')
    for key, value in trial.params.items():
        print('    {}: {}'.format(key, value))
# Out:
# train, val, test:  (105000, 200), (45000, 200), (50000, 200)
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's auc: 0.968792	valid_1's auc: 0.852637
# [2000]	training's auc: 0.991746	valid_1's auc: 0.875854
# [3000]	training's auc: 0.998006	valid_1's auc: 0.885266
# [4000]	training's auc: 0.999636	valid_1's auc: 0.889669
# [5000]	training's auc: 0.999954	valid_1's auc: 0.892089
# [6000]	training's auc: 0.999996	valid_1's auc: 0.893445
# [7000]	training's auc: 1	valid_1's auc: 0.894023
# Early stopping, best iteration is:
# [7211]	training's auc: 1	valid_1's auc: 0.894138
# [I 2019-03-03 21:43:07,165] Finished a trial resulted in value: 0.11350206398118623. Current best value is 0.11350206398118623 with parameters: {'pca_type': 'linear', 'pca_dim': 4, 'boosting': 'gbdt', 'num_leaves': 464, 'learning_rate': 0.0024376045374634877, 'min_data_in_leaf': 357, 'max_depth': 52}.

# %%
param = trial.params
param['objective'] = 'binary'
param['metric'] = 'auc'
param
# Out:
# {'boosting': 'gbdt',
#  'learning_rate': 0.027065938118566835,
#  'max_depth': 1,
#  'metric': 'auc',
#  'min_data_in_leaf': 733,
#  'num_leaves': 939,
#  'objective': 'binary',
#  'pca_dim': 16}

# %%
param = {'boosting': 'gbdt',
 'learning_rate': 0.027065938118566835,
 'max_depth': 1,
 'metric': 'auc',
 'min_data_in_leaf': 733,
 'num_leaves': 939,
 'objective': 'binary',
 'pca_dim': 0}
param['objective'] = 'binary'
param['metric'] = 'auc'

# %%
param = {'boosting': 'gbdt',
 'learning_rate': 0.02,
 'max_depth': 2,
 'metric': 'auc',
 'min_data_in_leaf': 750,
 'num_leaves': 3,
 'objective': 'binary',
 'pca_dim': 0,
'feature_fraction' : 0.8}
param['objective'] = 'binary'
param['metric'] = 'auc'

# %%
# %%time

# skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=2019)
skf = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=46)
oof = np.zeros(len(train_df))
predictions = np.zeros(len(test_df))
feature_importance_df = pd.DataFrame()

start = time.time()

for fold_, (trn_idx, val_idx) in enumerate(skf.split(train_df.values, target.values)):
    print("fold n°{}".format(fold_))
    train_X = np.array(train_df.iloc[trn_idx][features])
    train_y = np.array(target.iloc[trn_idx])
    
    val_X = np.array(train_df.iloc[val_idx][features])
    val_y = np.array(target.iloc[val_idx])
    
    test_X = np.array(test_df[features])
    
    if param["pca_dim"] > 0:
    #     pca = PCA(n_components=param["pca_dim"])
        pca = KernelPCA(n_components=16, kernel="rbf")

        train_X_transformed = pca.fit_transform(train_X)
        val_X_transformed = pca.transform(val_X)
        test_X_transformed =  pca.transform(test_X)

        train_X_expanded = np.hstack((train_X, train_X_transformed))
        val_X_expanded = np.hstack((val_X, val_X_transformed))
        test_X_expanded = np.hstack((test_X, test_X_transformed))
    else:
        train_X_expanded = train_X
        val_X_expanded = val_X
        test_X_expanded = test_X
    
    print("train:{}, val:{}, test:{}".format(train_X_expanded.shape, val_X_expanded.shape, test_X_expanded.shape))
    
    trn_data = lgb.Dataset(train_X_expanded, label=train_y)
    val_data = lgb.Dataset(val_X_expanded, label=val_y)
    

    num_round = 100000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds=300)
    oof[val_idx] = clf.predict(val_X_expanded, num_iteration=clf.best_iteration)
    
#     fold_importance_df = pd.DataFrame()
#     fold_importance_df["feature"] = features
#     fold_importance_df["importance"] = clf.feature_importance()
#     fold_importance_df["fold"] = fold_ + 1
#     feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test_X_expanded, num_iteration=clf.best_iteration) / 5

print("CV score: {:<8.5f}".format(roc_auc_score(target, oof)))
# Out:
# fold n°0
# train:(159999, 200), val:(40001, 200), test:(200000, 200)
# Training until validation scores don't improve for 300 rounds.
# [100]	training's auc: 0.743265	valid_1's auc: 0.743585
# [200]	training's auc: 0.78169	valid_1's auc: 0.781577
# [300]	training's auc: 0.802816	valid_1's auc: 0.801829
# [400]	training's auc: 0.817537	valid_1's auc: 0.815071
# [500]	training's auc: 0.829048	valid_1's auc: 0.825288
# [600]	training's auc: 0.837949	valid_1's auc: 0.832944
# [700]	training's auc: 0.845179	valid_1's auc: 0.839147
# [800]	training's auc: 0.850895	valid_1's auc: 0.843718
# [900]	training's auc: 0.855932	valid_1's auc: 0.84791
# [1000]	training's auc: 0.860565	valid_1's auc: 0.851709
# [1100]	training's auc: 0.864514	valid_1's auc: 0.85489
# [1200]	training's auc: 0.868066	valid_1's auc: 0.858005
# [1300]	training's auc: 0.871296	valid_1's auc: 0.860857
# [1400]	training's auc: 0.874058	valid_1's auc: 0.863089
# [1500]	training's auc: 0.876513	valid_1's auc: 0.865182
# [1600]	training's auc: 0.878733	valid_1's auc: 0.867045
# [1700]	training's auc: 0.880867	valid_1's auc: 0.868966
# [1800]	training's auc: 0.882859	valid_1's auc: 0.87064
# [1900]	training's auc: 0.884517	valid_1's auc: 0.87212
# [2000]	training's auc: 0.886258	valid_1's auc: 0.873571
# [2100]	training's auc: 0.887835	valid_1's auc: 0.874988
# [2200]	training's auc: 0.889293	valid_1's auc: 0.87612
# [2300]	training's auc: 0.890683	valid_1's auc: 0.877287
# [2400]	training's auc: 0.891894	valid_1's auc: 0.878334
# [2500]	training's auc: 0.893038	valid_1's auc: 0.87929
# [2600]	training's auc: 0.894188	valid_1's auc: 0.880152
# [2700]	training's auc: 0.895142	valid_1's auc: 0.88095
# [2800]	training's auc: 0.896135	valid_1's auc: 0.88171
# [2900]	training's auc: 0.897035	valid_1's auc: 0.882453
# [3000]	training's auc: 0.897979	valid_1's auc: 0.883199
# [3100]	training's auc: 0.898806	valid_1's auc: 0.88397
# [3200]	training's auc: 0.899634	valid_1's auc: 0.884606
# [3300]	training's auc: 0.900431	valid_1's auc: 0.885299
# [3400]	training's auc: 0.901192	valid_1's auc: 0.885858
# [3500]	training's auc: 0.901902	valid_1's auc: 0.886425
# [3600]	training's auc: 0.902534	valid_1's auc: 0.886953
# [3700]	training's auc: 0.903171	valid_1's auc: 0.887443
# [3800]	training's auc: 0.903794	valid_1's auc: 0.888012
# [3900]	training's auc: 0.904383	valid_1's auc: 0.888409
# [4000]	training's auc: 0.904932	valid_1's auc: 0.888827
# [4100]	training's auc: 0.905495	valid_1's auc: 0.889289
# [4200]	training's auc: 0.906013	valid_1's auc: 0.889663
# [4300]	training's auc: 0.90645	valid_1's auc: 0.889973
# [4400]	training's auc: 0.906956	valid_1's auc: 0.890385
# [4500]	training's auc: 0.907401	valid_1's auc: 0.890715
# [4600]	training's auc: 0.907898	valid_1's auc: 0.89109
# [4700]	training's auc: 0.908323	valid_1's auc: 0.89139
# [4800]	training's auc: 0.908755	valid_1's auc: 0.891763
# [4900]	training's auc: 0.909159	valid_1's auc: 0.892039
# [5000]	training's auc: 0.909569	valid_1's auc: 0.892302
# [5100]	training's auc: 0.909939	valid_1's auc: 0.89258
# [5200]	training's auc: 0.910306	valid_1's auc: 0.892838
# [5300]	training's auc: 0.910661	valid_1's auc: 0.893094
# [5400]	training's auc: 0.911037	valid_1's auc: 0.893328
# [5500]	training's auc: 0.911387	valid_1's auc: 0.89355
# [5600]	training's auc: 0.911719	valid_1's auc: 0.893771
# [5700]	training's auc: 0.912038	valid_1's auc: 0.893989
# [5800]	training's auc: 0.912355	valid_1's auc: 0.89419
# [5900]	training's auc: 0.912642	valid_1's auc: 0.894336
# [6000]	training's auc: 0.912935	valid_1's auc: 0.894498
# [6100]	training's auc: 0.913247	valid_1's auc: 0.894693
# [6200]	training's auc: 0.913501	valid_1's auc: 0.894876
# [6300]	training's auc: 0.913765	valid_1's auc: 0.895059
# [6400]	training's auc: 0.914035	valid_1's auc: 0.895207
# [6500]	training's auc: 0.914285	valid_1's auc: 0.895368
# [6600]	training's auc: 0.914534	valid_1's auc: 0.895478
# [6700]	training's auc: 0.91479	valid_1's auc: 0.895586
# [6800]	training's auc: 0.915031	valid_1's auc: 0.895711
# [6900]	training's auc: 0.915252	valid_1's auc: 0.895863
# [7000]	training's auc: 0.91548	valid_1's auc: 0.89601
# [7100]	training's auc: 0.915706	valid_1's auc: 0.896116
# [7200]	training's auc: 0.915941	valid_1's auc: 0.896224
# [7300]	training's auc: 0.916146	valid_1's auc: 0.896304
# [7400]	training's auc: 0.916402	valid_1's auc: 0.89644
# [7500]	training's auc: 0.916605	valid_1's auc: 0.896548
# [7600]	training's auc: 0.916836	valid_1's auc: 0.896624
# [7700]	training's auc: 0.917041	valid_1's auc: 0.896708
# [7800]	training's auc: 0.917249	valid_1's auc: 0.896824
# [7900]	training's auc: 0.917469	valid_1's auc: 0.896915
# [8000]	training's auc: 0.917668	valid_1's auc: 0.896998
# [8100]	training's auc: 0.917874	valid_1's auc: 0.897059
# [8200]	training's auc: 0.918099	valid_1's auc: 0.89715
# [8300]	training's auc: 0.918317	valid_1's auc: 0.897202
# [8400]	training's auc: 0.918504	valid_1's auc: 0.897294
# [8500]	training's auc: 0.918699	valid_1's auc: 0.89735
# [8600]	training's auc: 0.918905	valid_1's auc: 0.897382
# [8700]	training's auc: 0.919103	valid_1's auc: 0.89747
# [8800]	training's auc: 0.919301	valid_1's auc: 0.897497
# [8900]	training's auc: 0.919508	valid_1's auc: 0.897577
# [9000]	training's auc: 0.919697	valid_1's auc: 0.897626
# [9100]	training's auc: 0.919889	valid_1's auc: 0.897693
# [9200]	training's auc: 0.920074	valid_1's auc: 0.897744
# [9300]	training's auc: 0.920275	valid_1's auc: 0.897764
# [9400]	training's auc: 0.920471	valid_1's auc: 0.897847
# [9500]	training's auc: 0.920662	valid_1's auc: 0.89788
# [9600]	training's auc: 0.92084	valid_1's auc: 0.897916
# [9700]	training's auc: 0.921016	valid_1's auc: 0.89795
# [9800]	training's auc: 0.921199	valid_1's auc: 0.897975
# [9900]	training's auc: 0.92137	valid_1's auc: 0.898003
# [10000]	training's auc: 0.921555	valid_1's auc: 0.898071
# [10100]	training's auc: 0.921748	valid_1's auc: 0.89811
# [10200]	training's auc: 0.921918	valid_1's auc: 0.89815
# [10300]	training's auc: 0.92209	valid_1's auc: 0.898184
# [10400]	training's auc: 0.922256	valid_1's auc: 0.898199
# [10500]	training's auc: 0.922432	valid_1's auc: 0.898234
# [10600]	training's auc: 0.922605	valid_1's auc: 0.898282
# [10700]	training's auc: 0.922773	valid_1's auc: 0.898308
# [10800]	training's auc: 0.922935	valid_1's auc: 0.898338
# [10900]	training's auc: 0.923104	valid_1's auc: 0.8984
# [11000]	training's auc: 0.923286	valid_1's auc: 0.898433
# [11100]	training's auc: 0.923439	valid_1's auc: 0.898469
# [11200]	training's auc: 0.923602	valid_1's auc: 0.898477
# [11300]	training's auc: 0.923765	valid_1's auc: 0.898506
# [11400]	training's auc: 0.923924	valid_1's auc: 0.898536
# [11500]	training's auc: 0.924081	valid_1's auc: 0.898558
# [11600]	training's auc: 0.924239	valid_1's auc: 0.898589
# [11700]	training's auc: 0.924393	valid_1's auc: 0.898593
# [11800]	training's auc: 0.924535	valid_1's auc: 0.898616
# [11900]	training's auc: 0.924701	valid_1's auc: 0.898632
# [12000]	training's auc: 0.924843	valid_1's auc: 0.898678
# [12100]	training's auc: 0.924991	valid_1's auc: 0.898679
# [12200]	training's auc: 0.925133	valid_1's auc: 0.898688
# [12300]	training's auc: 0.92528	valid_1's auc: 0.898725
# [12400]	training's auc: 0.925439	valid_1's auc: 0.898745
# [12500]	training's auc: 0.925586	valid_1's auc: 0.898752
# [12600]	training's auc: 0.92573	valid_1's auc: 0.898767
# [12700]	training's auc: 0.925875	valid_1's auc: 0.898779
# [12800]	training's auc: 0.92602	valid_1's auc: 0.89878
# [12900]	training's auc: 0.926164	valid_1's auc: 0.898816
# [13000]	training's auc: 0.926302	valid_1's auc: 0.898828
# [13100]	training's auc: 0.926444	valid_1's auc: 0.898853
# [13200]	training's auc: 0.926585	valid_1's auc: 0.898873
# [13300]	training's auc: 0.926727	valid_1's auc: 0.898889
# [13400]	training's auc: 0.926866	valid_1's auc: 0.898897
# [13500]	training's auc: 0.927001	valid_1's auc: 0.898908
# [13600]	training's auc: 0.92714	valid_1's auc: 0.898893
# [13700]	training's auc: 0.927274	valid_1's auc: 0.898895
# Early stopping, best iteration is:
# [13435]	training's auc: 0.926911	valid_1's auc: 0.898914
# fold n°1
# train:(159999, 200), val:(40001, 200), test:(200000, 200)
# Training until validation scores don't improve for 300 rounds.
# [100]	training's auc: 0.738474	valid_1's auc: 0.736984
# [200]	training's auc: 0.781178	valid_1's auc: 0.779462
# [300]	training's auc: 0.801397	valid_1's auc: 0.799057
# [400]	training's auc: 0.815361	valid_1's auc: 0.81226
# [500]	training's auc: 0.827149	valid_1's auc: 0.823673
# [600]	training's auc: 0.836469	valid_1's auc: 0.832636
# [700]	training's auc: 0.84345	valid_1's auc: 0.839023
# [800]	training's auc: 0.84937	valid_1's auc: 0.844544
# [900]	training's auc: 0.854739	valid_1's auc: 0.849322
# [1000]	training's auc: 0.859324	valid_1's auc: 0.853552
# [1100]	training's auc: 0.86331	valid_1's auc: 0.857076
# [1200]	training's auc: 0.867047	valid_1's auc: 0.860352
# [1300]	training's auc: 0.870282	valid_1's auc: 0.863251
# [1400]	training's auc: 0.873166	valid_1's auc: 0.86569
# [1500]	training's auc: 0.875687	valid_1's auc: 0.867827
# [1600]	training's auc: 0.87795	valid_1's auc: 0.869756
# [1700]	training's auc: 0.880056	valid_1's auc: 0.871576
# [1800]	training's auc: 0.882004	valid_1's auc: 0.873305
# [1900]	training's auc: 0.883828	valid_1's auc: 0.874868
# [2000]	training's auc: 0.885447	valid_1's auc: 0.876362
# [2100]	training's auc: 0.886995	valid_1's auc: 0.87772
# [2200]	training's auc: 0.888427	valid_1's auc: 0.87893
# [2300]	training's auc: 0.889761	valid_1's auc: 0.880155
# [2400]	training's auc: 0.891018	valid_1's auc: 0.881249
# [2500]	training's auc: 0.892243	valid_1's auc: 0.882234
# [2600]	training's auc: 0.893377	valid_1's auc: 0.88329
# [2700]	training's auc: 0.894375	valid_1's auc: 0.884099
# [2800]	training's auc: 0.895329	valid_1's auc: 0.884896
# [2900]	training's auc: 0.896364	valid_1's auc: 0.88566
# [3000]	training's auc: 0.897167	valid_1's auc: 0.886381
# [3100]	training's auc: 0.898015	valid_1's auc: 0.88706
# [3200]	training's auc: 0.898852	valid_1's auc: 0.887703
# [3300]	training's auc: 0.89963	valid_1's auc: 0.888389
# [3400]	training's auc: 0.900363	valid_1's auc: 0.889055
# [3500]	training's auc: 0.901095	valid_1's auc: 0.889628
# [3600]	training's auc: 0.901747	valid_1's auc: 0.890134
# [3700]	training's auc: 0.902371	valid_1's auc: 0.890631
# [3800]	training's auc: 0.90297	valid_1's auc: 0.891156
# [3900]	training's auc: 0.903598	valid_1's auc: 0.891655
# [4000]	training's auc: 0.904122	valid_1's auc: 0.892098
# [4100]	training's auc: 0.904659	valid_1's auc: 0.892525
# [4200]	training's auc: 0.905212	valid_1's auc: 0.892925
# [4300]	training's auc: 0.905734	valid_1's auc: 0.893329
# [4400]	training's auc: 0.906241	valid_1's auc: 0.893729
# [4500]	training's auc: 0.906688	valid_1's auc: 0.894091
# [4600]	training's auc: 0.907165	valid_1's auc: 0.894515
# [4700]	training's auc: 0.907606	valid_1's auc: 0.894885
# [4800]	training's auc: 0.908033	valid_1's auc: 0.895183
# [4900]	training's auc: 0.908471	valid_1's auc: 0.895559
# [5000]	training's auc: 0.908849	valid_1's auc: 0.895804
# [5100]	training's auc: 0.909203	valid_1's auc: 0.896098
# [5200]	training's auc: 0.909574	valid_1's auc: 0.896321
# [5300]	training's auc: 0.909938	valid_1's auc: 0.8966
# [5400]	training's auc: 0.910284	valid_1's auc: 0.896872
# [5500]	training's auc: 0.910635	valid_1's auc: 0.897079
# [5600]	training's auc: 0.910969	valid_1's auc: 0.897318
# [5700]	training's auc: 0.911296	valid_1's auc: 0.89748
# [5800]	training's auc: 0.9116	valid_1's auc: 0.897706
# [5900]	training's auc: 0.911885	valid_1's auc: 0.897862
# [6000]	training's auc: 0.912188	valid_1's auc: 0.898048
# [6100]	training's auc: 0.912471	valid_1's auc: 0.898249
# [6200]	training's auc: 0.912731	valid_1's auc: 0.898381
# [6300]	training's auc: 0.913002	valid_1's auc: 0.898549
# [6400]	training's auc: 0.913245	valid_1's auc: 0.89866
# [6500]	training's auc: 0.913513	valid_1's auc: 0.898814
# [6600]	training's auc: 0.913743	valid_1's auc: 0.898974
# [6700]	training's auc: 0.914004	valid_1's auc: 0.899119
# [6800]	training's auc: 0.914272	valid_1's auc: 0.899291
# [6900]	training's auc: 0.914503	valid_1's auc: 0.8994
# [7000]	training's auc: 0.914749	valid_1's auc: 0.899514

# %%
sub_df1 = pd.DataFrame({"ID_code":test_df["ID_code"].values})
sub_df1["target"] = predictions
sub_df1.to_csv("0303_lgbm_kernelPCA.csv", index=False)

# %%
sub_df1
# Out:
#             ID_code    target
# 0            test_0  0.084756
# 1            test_1  0.189936
# 2            test_2  0.211091
# 3            test_3  0.193036
# 4            test_4  0.049279
# 5            test_5  0.001665
# 6            test_6  0.005571
# 7            test_7  0.199931
# 8            test_8  0.002534
# 9            test_9  0.006682
# 10          test_10  0.316455
# 11          test_11  0.032745
# 12          test_12  0.040548
# 13          test_13  0.020346
# 14          test_14  0.005881
# 15          test_15  0.027633
# 16          test_16  0.353675
# 17          test_17  0.025767
# 18          test_18  0.173617
# 19          test_19  0.008513
# 20          test_20  0.312857
# 21          test_21  0.079968
# 22          test_22  0.007116
# 23          test_23  0.043555
# 24          test_24  0.013313
# 25          test_25  0.106726
# 26          test_26  0.081627
# 27          test_27  0.014067
# 28          test_28  0.330429
# 29          test_29  0.095799
# ...             ...       ...
# 199970  test_199970  0.056007
# 199971  test_199971  0.136933
# 199972  test_199972  0.004743
# 199973  test_199973  0.077278
# 199974  test_199974  0.005940
# 199975  test_199975  0.084978
# 199976  test_199976  0.177759
# 199977  test_199977  0.195962
# 199978  test_199978  0.027084
# 199979  test_199979  0.062641
# 199980  test_199980  0.053432
# 199981  test_199981  0.043914
# 199982  test_199982  0.022690
# 199983  test_199983  0.034402
# 199984  test_199984  0.015330
# 199985  test_199985  0.144580
# 199986  test_199986  0.553207
# 199987  test_199987  0.042183
# 199988  test_199988  0.012413
# 199989  test_199989  0.035469
# 199990  test_199990  0.004363
# 199991  test_199991  0.005403
# 199992  test_199992  0.298859
# 199993  test_199993  0.011364
# 199994  test_199994  0.076246
# 199995  test_199995  0.038828
# 199996  test_199996  0.007382
# 199997  test_199997  0.002826
# 199998  test_199998  0.090087
# 199999  test_199999  0.093756
#
# [200000 rows x 2 columns]

# %% [markdown]
# # Logistic Regression

# %%
# Data processing, metrics and modeling
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# Find best hyperparameters (roc_auc)
# random_state = 42
# log_clf = LogisticRegression(random_state = random_state, n_jobs=-1)
# data = np.array(train_df[features])
# target = np.asarray(train_df['target'])
# log_clf.fit(data[:int(len(data)*0.8)], target[:int(len(data)*0.8)])

# %%
data = np.array(train_df[features])
target = np.asarray(train_df['target'])

dev_x, test_x, dev_y, test_y = train_test_split(data, target, test_size=0.25, stratify=target, random_state=2018)
train_x, val_x, train_y, val_y = train_test_split(dev_x, dev_y, test_size=0.25, stratify=dev_y,  random_state=2018)

def objective(trial):
    param = {
        'class_weight' : trial.suggest_categorical("class_weight", ['balanced', None]),
        'penalty' : trial.suggest_categorical("penalty", ['l2','l1']),  
        'C' :  trial.suggest_loguniform('C', 0.0001, 1000)
    }
    
    
    print("train, val, test:  {}, {}, {}".format(train_x.shape, val_x.shape, test_x.shape))
    log_clf = LogisticRegression(random_state=46, n_jobs=-1)
    log_clf.fit(dev_x, dev_y)
    
    preds = log_clf.predict_proba(test_x)[:, 1]

    auc_score = roc_auc_score(test_y, preds)
    return 1.0 - auc_score


if __name__ == '__main__':
    study = optuna.create_study()
    study.optimize(objective, n_trials=25)

    print('Number of finished trials: {}'.format(len(study.trials)))

    print('Best trial:')
    trial = study.best_trial

    print('  Value: {}'.format(trial.value))

    print('  Params: ')
    for key, value in trial.params.items():
        print('    {}: {}'.format(key, value))
# Out:
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:14:16,659] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:17:43,453] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:21:10,052] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:24:36,719] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:28:06,812] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:31:37,041] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:35:03,395] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:38:36,213] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:42:02,629] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:45:31,240] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:48:57,984] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:52:25,719] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:55:52,857] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 01:59:23,239] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 02:02:50,094] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 02:06:17,818] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 02:09:44,317] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# [I 2019-03-02 02:13:11,212] Finished a trial resulted in value: 0.14617236765482267. Current best value is 0.14617236765482267 with parameters: {'class_weight': None, 'penalty': 'l1', 'C': 299.5277743545481}.
# train, val, test:  (112500, 200), (37500, 200), (50000, 200)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ff2e4d4e5af6> in <module>()
#      25 if __name__ == '__main__':
#      26     study = optuna.create_study()
# ---> 27     study.optimize(objective, n_trials=25)
#      28
#      29     print('Number of finished trials: {}'.format(len(study.trials)))
#
# /anaconda3/lib/python3.6/site-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch)
#     220
#     221         if n_jobs == 1:
# --> 222             self._optimize_sequential(func, n_trials, timeout, catch)
#     223         else:
#     224             self._optimize_parallel(func, n_trials, timeout, n_jobs, catch)
#
# /anaconda3/lib/python3.6/site-packages/optuna/study.py in _optimize_sequential(self, func, n_trials, timeout, catch)
#     334                     break
#     335
# --> 336             self._run_trial(func, catch)
#     337
#     338     def _optimize_parallel(
#
# /anaconda3/lib/python3.6/site-packages/optuna/study.py in _run_trial(self, func, catch)
#     407
#     408         try:
# --> 409             result = func(trial)
#     410         except structs.TrialPruned as e:
#     411             message = 'Setting trial status as {}. {}'.format(
#
# <ipython-input-7-ff2e4d4e5af6> in objective(trial)
#      15     print("train, val, test:  {}, {}, {}".format(train_x.shape, val_x.shape, test_x.shape))
#      16     log_clf = LogisticRegression(random_state=46, n_jobs=-1)
# ---> 17     log_clf.fit(dev_x, dev_y)
#      18
#      19     preds = log_clf.predict_proba(test_x)[:, 1]
#
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1299                 self.class_weight, self.penalty, self.dual, self.verbose,
#    1300                 self.max_iter, self.tol, self.random_state,
# -> 1301                 sample_weight=sample_weight)
#    1302             self.n_iter_ = np.array([n_iter_])
#    1303             return self
#
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     912         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     913         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 914         epsilon, sample_weight)
#     915     # Regarding rnd.randint(..) in the above signature:
#     916     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:

# %%
log_clf = LogisticRegression(**best_parameters)
log_clf.fit(data, target)

selector = RFE(log_clf, 25, step=1)
selector.fit(data, target)
scores_table(selector, 'selector_clf')

# %%
submission = pd.read_csv('../input/sample_submission.csv')
X_test = np.array(test_df[features])

submission['target'] = selector.predict_proba(X_test)
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler

data = np.array(train_df[features])
target_arr = np.asarray(train_df['target'])

dev_x, test_x, dev_y, test_y = train_test_split(data, target_arr, test_size=0.25, stratify=target, random_state=2018)
train_x, val_x, train_y, val_y = train_test_split(dev_x, dev_y, test_size=0.25, stratify=dev_y,  random_state=2018)

scaler = StandardScaler()
scaler.fit(dev_x)

dev_x = scaler.transform(dev_x)
test_x = scaler.transform(test_x)


def objective(trial):
    param = {
        "hidden_layer_sizes" : trial.suggest_int("hidden_layer_sizes", 1, 10),
        "hidden_units" :  trial.suggest_int("hidden_units", 30, 2000),
        'learning_rate_init' :  trial.suggest_loguniform('learning_rate_init', 0.0001, 1.0)
    }
    
    hidden_layer = tuple([param["hidden_units"] for _ in range(param["hidden_layer_sizes"])])
    
    mlp = MLPClassifier(max_iter=100000, early_stopping=True, n_iter_no_change=50, hidden_layer_sizes=hidden_layer,
                                       learning_rate_init=param["learning_rate_init"])
    mlp.fit(dev_x, dev_y)
    
    preds = mlp.predict_proba(test_x)[:, 1]

    auc_score = roc_auc_score(test_y, preds)
    return 1.0 - auc_score


study = optuna.create_study()
study.optimize(objective, n_trials=25)

print('Number of finished trials: {}'.format(len(study.trials)))

print('Best trial:')
trial = study.best_trial

print('  Value: {}'.format(trial.value))

print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
# Out:
# [I 2019-03-04 09:37:51,089] Finished a trial resulted in value: 0.16134424205294484. Current best value is 0.16134424205294484 with parameters: {'hidden_layer_sizes': 2, 'hidden_units': 1457, 'learning_rate_init': 0.0023461738566405896}.
# [I 2019-03-04 09:51:18,487] Finished a trial resulted in value: 0.15905601927893032. Current best value is 0.15905601927893032 with parameters: {'hidden_layer_sizes': 10, 'hidden_units': 82, 'learning_rate_init': 0.02241354539732331}.
# [I 2019-03-04 10:06:46,547] Finished a trial resulted in value: 0.16291920181209163. Current best value is 0.15905601927893032 with parameters: {'hidden_layer_sizes': 10, 'hidden_units': 82, 'learning_rate_init': 0.02241354539732331}.
# [I 2019-03-04 10:59:42,304] Finished a trial resulted in value: 0.5. Current best value is 0.15905601927893032 with parameters: {'hidden_layer_sizes': 10, 'hidden_units': 82, 'learning_rate_init': 0.02241354539732331}.
# [I 2019-03-04 15:02:10,991] Finished a trial resulted in value: 0.15544872339557747. Current best value is 0.15544872339557747 with parameters: {'hidden_layer_sizes': 6, 'hidden_units': 1020, 'learning_rate_init': 0.0004586022013911475}.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-91d4ae27890e>", line 37, in <module>
#     study.optimize(objective, n_trials=25)
#   File "/anaconda3/lib/python3.6/site-packages/optuna/study.py", line 222, in optimize
#     self._optimize_sequential(func, n_trials, timeout, catch)
#   File "/anaconda3/lib/python3.6/site-packages/optuna/study.py", line 336, in _optimize_sequential
#     self._run_trial(func, catch)
#   File "/anaconda3/lib/python3.6/site-packages/optuna/study.py", line 409, in _run_trial
#     result = func(trial)
#   File "<ipython-input-6-91d4ae27890e>", line 30, in objective
#     preds = mlp.predict_proba(test_x)[:, 1]
#   File "/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py", line 1054, in predict_proba
#     y_pred = self._predict(X)
#   File "/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py", line 658, in _predict
#     X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#   File "/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py", line 568, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py", line 49, in _assert_all_finite
#     if is_float and np.isfinite(X.sum()):
#   File "/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 32, in _sum
#     return umr_sum(a, axis, dtype, out, keepdims)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# KeyboardInterrupt
